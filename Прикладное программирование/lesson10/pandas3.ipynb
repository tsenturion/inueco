# %%
import pandas as pd

#Series с индексом
fruit_series = pd.Series([15, 40, 23], index=['яблоки', 'бананы', 'апельсины'])
print(fruit_series)

#DataFrame с данными о продуктах
products_data = {
    'название': ['Молоко', 'Хлеб', 'Сыр', 'Шоколад'],
    'цена': [85, 45, 350, 120],
    'количество': [20, 50, 10, 15]
}

products_df = pd.DataFrame(products_data)
print(products_df)

print("Эксперименты:")
print(fruit_series['бананы'])

products_df['общая_стоимость'] = products_df['цена'] * products_df['количество']
print(products_df)

print(products_df[products_df['цена'] > 100])
# Out:
# яблоки       15
# бананы       40
# апельсины    23
# dtype: int64
#   название  цена  количество
# 0   Молоко    85          20
# 1     Хлеб    45          50
# 2      Сыр   350          10
# 3  Шоколад   120          15
# Эксперименты:
# 40
#   название  цена  количество  общая_стоимость
# 0   Молоко    85          20             1700
# 1     Хлеб    45          50             2250
# 2      Сыр   350          10             3500
# 3  Шоколад   120          15             1800
#   название  цена  количество  общая_стоимость
# 2      Сыр   350          10             3500
# 3  Шоколад   120          15             1800
