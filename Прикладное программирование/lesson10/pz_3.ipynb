# %%
import pandas as pd

#Series
fruit_series = pd.Series([24, 22, 71], index=['Яблоки', 'Бананы', 'Апельсины'])
print("Series c индексом", "\n")
print(fruit_series)
print("-" * 40)

#DataFrame 
products_data = {
    'Название': ['Стимулятор', 'Банка', 'Сыр', 'синтоМясо', 'Пицца'],
    'Цена': [105 , 50, 250, 152, 180],
    'Количество': [22, 52, 20, 15, 30]
}
product = pd.DataFrame(products_data)
print("DataFrame с данными", "\n")
print(product) 
print("-" * 40)

# Задание 3
print("Эксперименты:" , fruit_series['Бананы'], "\n")
product['Общ стоимость'] = product['Цена'] * product['Количество']
print(product , "\n")
# Out:
# Series c индексом
#
# Яблоки       24
# Бананы       22
# Апельсины    71
# dtype: int64
# ----------------------------------------
# DataFrame с данными
#
#      Название  Цена  Количество
# 0  Стимулятор   105          22
# 1       Банка    50          52
# 2         Сыр   250          20
# 3   синтоМясо   152          15
# 4       Пицца   180          30
# ----------------------------------------
# Эксперименты: 22
#
#      Название  Цена  Количество  Общ стоимость
# 0  Стимулятор   105          22           2310
# 1       Банка    50          52           2600
# 2         Сыр   250          20           5000
# 3   синтоМясо   152          15           2280
# 4       Пицца   180          30           5400
