# %%
import pandas as pd

#Версия pandos
print(pd.__version__)

#series с числами
fav_numbers = pd.Series([7, 12, 25, 100, 3])
print(fav_numbers)

#DataFrame
data = {
    "Name": ["AmerikanTolya", "Misha", "Ivan", "Max"],
    "Age": [24, 25, 22, 23],
    "City": ["NewYork", "Perm", "Sochi", "Moskow"]
}

df = pd.DataFrame(data)

#4 T
print(df.head())
df.info()
#5 средний возраст
print(df["Age"].mean())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 #Версия pandos
#       4 print(pd.__version__)
#
# ModuleNotFoundError: No module named 'pandas'
